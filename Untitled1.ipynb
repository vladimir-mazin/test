# %% [markdown]
# Bragg experiment
# Characterization of X-ray Emission of Different Metals
# 13.02.2025, set #1
#
# Mo 35 kEv, 1 mA
#
# Vladimir Mazin

# %% [markdown]
# Goal: The determination of the enegry of characteristic radiation of Molybdenum

# %% [markdown]
# Preparation questions
# Siegbahn notation of electron transitions responsible for the characteristic radiation
#
# (By ​English wikipedia user HenrikMidtiby, CC BY-SA 3.0, https://commons.wikimedia.org/w/index.php?curid=7240759)
#
# ![CharacteristicRadiation.svg]

# %% [markdown]
# Both LiF and KBr have face-centered cubic crystal lattice with the lattice constant equal to 0.403 and 0.659 nm correspondingly. The extinction rules for this type of lattice are : h, k, l all odd or all even, thus the first observable diffraction peaks have (200) indces.

# %% [markdown]
# LiF crystal
# tube	Mo
# diafragm	2
# interplanar spacing	201
# voltage	35
# current	1
# coupling mode	1 :2
# angle range 	3 - 75
# increment	0.1

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import find_peaks

# %% [markdown]
# Load measurement data

# %%
filename = 'https://github.com/vladimir-mazin/test/blob/main/lif.txt'
_, rate, _, _, _, theta = np.genfromtxt(filename, unpack=True, skip_header=3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-c7a249ba5e41> in <cell line: 0>()
#       1 filename = 'https://github.com/vladimir-mazin/test/blob/main/lif.txt'
# ----> 2 _, rate, _, _, _, theta = np.genfromtxt(filename, unpack=True, skip_header=3)
#
# /usr/local/lib/python3.11/dist-packages/numpy/lib/npyio.py in genfromtxt(fname, dtype, comments, delimiter, skip_header, skip_footer, converters, missing_values, filling_values, usecols, names, excludelist, deletechars, replace_space, autostrip, case_sensitive, defaultfmt, unpack, usemask, loose, invalid_raise, max_rows, encoding, ndmin, like)
#    2310             # Raise an exception ?
#    2311             if invalid_raise:
# -> 2312                 raise ValueError(errmsg)
#    2313             # Issue a warning ?
#    2314             else:
#
# ValueError: Some errors were detected !
#     Line #5 (got 1 columns instead of 2)
#     Line #6 (got 1 columns instead of 2)
#     Line #8 (got 3 columns instead of 2)
#     Line #11 (got 1 columns instead of 2)
#     Line #15 (got 1 columns instead of 2)
#     Line #17 (got 3 columns instead of 2)
#     Line #18 (got 3 columns instead of 2)
#     Line #19 (got 3 columns instead of 2)
#     Line #20 (got 3 columns instead of 2)
#     Line #21 (got 4 columns instead of 2)
#     Line #22 (got 3 columns instead of 2)
#     Line #27 (got 53 columns instead of 2)
#     Line #29 (got 6 columns instead of 2)
#     Line #30 (got 6 columns instead of 2)
#     Line #31 (got 6 columns instead of 2)
#     Line #32 (got 6 columns instead of 2)
#     Line #33 (got 6 columns instead of 2)
#     Line #34 (got 6 columns instead of 2)
#     Line #39 (got 3 columns instead of 2)
#     Line #40 (got 5 columns instead of 2)
#     Line #41 (got 5 columns instead of 2)
#     Line #42 (got 5 columns instead of 2)
#     Line #43 (got 5 columns instead of 2)
#     Line #44 (got 5 columns instead of 2)
#     Line #45 (got 5 columns instead of 2)
#     Line #46 (got 5 columns instead of 2)
#     Line #47 (got 5 columns instead of 2)
#     Line #48 (got 5 columns instead of 2)
#     Line #49 (got 5 columns instead of 2)
#     Line #50 (got 5 columns instead of 2)
#     Line #51 (got 5 columns instead of 2)
#     Line #52 (got 5 columns instead of 2)
#     Line #53 (got 5 columns instead of 2)
#     Line #54 (got 5 columns instead of 2)
#     Line #55 (got 5 columns instead of 2)
#     Line #56 (got 5 columns instead of 2)
#     Line #57 (got 5 columns instead of 2)
#     Line #58 (got 5 columns instead of 2)
#     Line #59 (got 5 columns instead of 2)
#     Line #60 (got 5 columns instead of 2)
#     Line #61 (got 5 columns instead of 2)
#     Line #62 (got 5 columns instead of 2)
#     Line #63 (got 5 columns instead of 2)
#     Line #64 (got 5 columns instead of 2)
#     Line #65 (got 5 columns instead of 2)
#     Line #66 (got 5 columns instead of 2)
#     Line #67 (got 5 columns instead of 2)
#     Line #68 (got 5 columns instead of 2)
#     Line #69 (got 5 columns instead of 2)
#     Line #70 (got 5 columns instead of 2)
#     Line #71 (got 5 columns instead of 2)
#     Line #73 (got 5 columns instead of 2)
#     Line #74 (got 5 columns instead of 2)
#     Line #75 (got 5 columns instead of 2)
#     Line #76 (got 5 columns instead of 2)
#     Line #77 (got 5 columns instead of 2)
#     Line #78 (got 5 columns instead of 2)
#     Line #79 (got 5 columns instead of 2)
#     Line #80 (got 5 columns instead of 2)
#     Line #81 (got 5 columns instead of 2)
#     Line #82 (got 5 columns instead of 2)
#     Line #83 (got 5 columns instead of 2)
#     Line #84 (got 5 columns instead of 2)
#     Line #85 (got 5 columns instead of 2)
#     Line #86 (got 5 columns instead of 2)
#     Line #87 (got 5 columns instead of 2)
#     Line #88 (got 5 columns instead of 2)
#     Line #89 (got 5 columns instead of 2)
#     Line #90 (got 5 columns instead of 2)
#     Line #91 (got 5 columns instead of 2)
#     Line #92 (got 6 columns instead of 2)
#     Line #93 (got 6 columns instead of 2)
#     Line #95 (got 5 columns instead of 2)
#     Line #96 (got 6 columns instead of 2)
#     Line #97 (got 6 columns instead of 2)
#     Line #100 (got 7 columns instead of 2)
#     Line #104 (got 4 columns instead of 2)
#     Line #105 (got 4 columns instead of 2)
#     Line #106 (got 4 columns instead of 2)
#     Line #109 (got 3 columns instead of 2)
#     Line #112 (got 13 columns instead of 2)
#     Line #115 (got 4 columns instead of 2)
#     Line #118 (got 5 columns instead of 2)
#     Line #121 (got 4 columns instead of 2)
#     Line #122 (got 3 columns instead of 2)
#     Line #124 (got 3 columns instead of 2)
#     Line #126 (got 4 columns instead of 2)
#     Line #128 (got 5 columns instead of 2)
#     Line #135 (got 3 columns instead of 2)
#     Line #139 (got 3 columns instead of 2)
#     Line #143 (got 12 columns instead of 2)
#     Line #145 (got 5 columns instead of 2)
#     Line #147 (got 4 columns instead of 2)
#     Line #148 (got 3 columns instead of 2)
#     Line #149 (got 5 columns instead of 2)
#     Line #151 (got 29 columns instead of 2)
#     Line #152 (got 50 columns instead of 2)
#     Line #158 (got 3 columns instead of 2)
#     Line #162 (got 3 columns instead of 2)
#     Line #165 (got 4 columns instead of 2)
#     Line #166 (got 4 columns instead of 2)
#     Line #167 (got 4 columns instead of 2)
#     Line #168 (got 4 columns instead of 2)
#     Line #170 (got 4 columns instead of 2)
#     Line #172 (got 4 columns instead of 2)
#     Line #175 (got 5 columns instead of 2)
#     Line #177 (got 25 columns instead of 2)
#     Line #183 (got 5 columns instead of 2)
#     Line #186 (got 3 columns instead of 2)
#     Line #188 (got 3 columns instead of 2)
#     Line #190 (got 4 columns instead of 2)
#     Line #191 (got 6 columns instead of 2)
#     Line #192 (got 6 columns instead of 2)
#     Line #194 (got 3 columns instead of 2)
#     Line #195 (got 5 columns instead of 2)
#     Line #198 (got 4 columns instead of 2)
#     Line #200 (got 1 columns instead of 2)
#     Line #202 (got 6 columns instead of 2)
#     Line #203 (got 7 columns instead of 2)
#     Line #207 (got 5 columns instead of 2)
#     Line #210 (got 6 columns instead of 2)
#     Line #211 (got 9 columns instead of 2)
#     Line #212 (got 1 columns instead of 2)
#     Line #214 (got 5 columns instead of 2)
#     Line #215 (got 5 columns instead of 2)
#     Line #216 (got 6 columns instead of 2)
#     Line #218 (got 1 columns instead of 2)
#     Line #219 (got 1 columns instead of 2)
#     Line #220 (got 1 columns instead of 2)
#     Line #221 (got 1 columns instead of 2)
#     Line #222 (got 1 columns instead of 2)
#     Line #224 (got 3 columns instead of 2)
#     Line #226 (got 1 columns instead of 2)
#     Line #236 (got 5 columns instead of 2)
#     Line #237 (got 5 columns instead of 2)
#     Line #238 (got 13 columns instead of 2)
#     Line #239 (got 3 columns instead of 2)
#     Line #241 (got 13 columns instead of 2)
#     Line #242 (got 3 columns instead of 2)
#     Line #243 (got 1 columns instead of 2)
#     Line #245 (got 11 columns instead of 2)
#     Line #246 (got 6 columns instead of 2)
#     Line #248 (got 17 columns instead of 2)
#     Line #249 (got 5 columns instead of 2)
#     Line #250 (got 4 columns instead of 2)
#     Line #251 (got 4 columns instead of 2)
#     Line #252 (got 1 columns instead of 2)
#     Line #253 (got 1 columns instead of 2)
#     Line #254 (got 1 columns instead of 2)
#     Line #256 (got 5 columns instead of 2)
#     Line #257 (got 1 columns instead of 2)
#     Line #258 (got 1 columns instead of 2)
#     Line #259 (got 6 columns instead of 2)
#     Line #260 (got 12 columns instead of 2)
#     Line #261 (got 63 columns instead of 2)
#     Line #262 (got 1 columns instead of 2)
#     Line #263 (got 1 columns instead of 2)
#     Line #265 (got 4 columns instead of 2)
#     Line #266 (got 1 columns instead of 2)
#     Line #267 (got 1 columns instead of 2)
#     Line #268 (got 14 columns instead of 2)
#     Line #269 (got 4 columns instead of 2)
#     Line #270 (got 6 columns instead of 2)
#     Line #271 (got 1 columns instead of 2)
#     Line #273 (got 1 columns instead of 2)
#     Line #274 (got 1 columns instead of 2)
#     Line #275 (got 1 columns instead of 2)
#     Line #278 (got 9 columns instead of 2)
#     Line #279 (got 9 columns instead of 2)
#     Line #280 (got 3 columns instead of 2)
#     Line #281 (got 3 columns instead of 2)
#     Line #282 (got 12 columns instead of 2)
#     Line #283 (got 15 columns instead of 2)
#     Line #284 (got 1 columns instead of 2)
#     Line #285 (got 15 columns instead of 2)
#     Line #286 (got 24 columns instead of 2)
#     Line #287 (got 1 columns instead of 2)
#     Line #288 (got 1 columns instead of 2)
#     Line #289 (got 17 columns instead of 2)
#     Line #290 (got 7 columns instead of 2)
#     Line #291 (got 5 columns instead of 2)
#     Line #292 (got 4 columns instead of 2)
#     Line #293 (got 1 columns instead of 2)
#     Line #294 (got 13 columns instead of 2)
#     Line #295 (got 14 columns instead of 2)
#     Line #296 (got 147 columns instead of 2)
#     Line #297 (got 1 columns instead of 2)
#     Line #298 (got 1 columns instead of 2)
#     Line #299 (got 4 columns instead of 2)
#     Line #300 (got 5 columns instead of 2)
#     Line #301 (got 1 columns instead of 2)
#     Line #304 (got 1 columns instead of 2)
#     Line #306 (got 1 columns instead of 2)
#     Line #307 (got 13 columns instead of 2)
#     Line #308 (got 14 columns instead of 2)
#     Line #309 (got 73 columns instead of 2)
#     Line #310 (got 1 columns instead of 2)
#     Line #311 (got 1 columns instead of 2)
#     Line #312 (got 3 columns instead of 2)
#     Line #313 (got 4 columns instead of 2)
#     Line #314 (got 1 columns instead of 2)
#     Line #317 (got 1 columns instead of 2)
#     Line #319 (got 1 columns instead of 2)
#     Line #320 (got 13 columns instead of 2)
#     Line #321 (got 14 columns instead of 2)
#     Line #322 (got 83 columns instead of 2)
#     Line #323 (got 1 columns instead of 2)
#     Line #324 (got 1 columns instead of 2)
#     Line #325 (got 3 columns instead of 2)
#     Line #326 (got 3 columns instead of 2)
#     Line #327 (got 1 columns instead of 2)
#     Line #330 (got 1 columns instead of 2)
#     Line #332 (got 1 columns instead of 2)
#     Line #333 (got 13 columns instead of 2)
#     Line #334 (got 14 columns instead of 2)
#     Line #335 (got 88 columns instead of 2)
#     Line #336 (got 1 columns instead of 2)
#     Line #337 (got 1 columns instead of 2)
#     Line #338 (got 3 columns instead of 2)
#     Line #339 (got 3 columns instead of 2)
#     Line #340 (got 1 columns instead of 2)
#     Line #343 (got 1 columns instead of 2)
#     Line #345 (got 1 columns instead of 2)
#     Line #346 (got 13 columns instead of 2)
#     Line #347 (got 14 columns instead of 2)
#     Line #348 (got 54 columns instead of 2)
#     Line #349 (got 1 columns instead of 2)
#     Line #350 (got 1 columns instead of 2)
#     Line #351 (got 3 columns instead of 2)
#     Line #352 (got 4 columns instead of 2)
#     Line #353 (got 1 columns instead of 2)
#     Line #356 (got 1 columns instead of 2)
#     Line #358 (got 1 columns instead of 2)
#     Line #359 (got 13 columns instead of 2)
#     Line #360 (got 14 columns instead of 2)
#     Line #361 (got 80 columns instead of 2)
#     Line #362 (got 1 columns instead of 2)
#     Line #363 (got 1 columns instead of 2)
#     Line #364 (got 4 columns instead of 2)
#     Line #365 (got 3 columns instead of 2)
#     Line #366 (got 1 columns instead of 2)
#     Line #369 (got 1 columns instead of 2)
#     Line #371 (got 1 columns instead of 2)
#     Line #372 (got 13 columns instead of 2)
#     Line #373 (got 14 columns instead of 2)
#     Line #374 (got 100 columns instead of 2)
#     Line #375 (got 1 columns instead of 2)
#     Line #376 (got 1 columns instead of 2)
#     Line #377 (got 3 columns instead of 2)
#     Line #378 (got 4 columns instead of 2)
#     Line #379 (got 1 columns instead of 2)
#     Line #382 (got 1 columns instead of 2)
#     Line #384 (got 1 columns instead of 2)
#     Line #385 (got 12 columns instead of 2)
#     Line #386 (got 14 columns instead of 2)
#     Line #387 (got 70 columns instead of 2)
#     Line #388 (got 1 columns instead of 2)
#     Line #389 (got 1 columns instead of 2)
#     Line #390 (got 4 columns instead of 2)
#     Line #391 (got 4 columns instead of 2)
#     Line #392 (got 1 columns instead of 2)
#     Line #395 (got 1 columns instead of 2)
#     Line #397 (got 1 columns instead of 2)
#     Line #398 (got 1 columns instead of 2)
#     Line #399 (got 1 columns instead of 2)
#     Line #400 (got 3 columns instead of 2)
#     Line #401 (got 6 columns instead of 2)
#     Line #402 (got 6 columns instead of 2)
#     Line #403 (got 4 columns instead of 2)
#     Line #404 (got 1 columns instead of 2)
#     Line #405 (got 9 columns instead of 2)
#     Line #409 (got 1 columns instead of 2)
#     Line #411 (got 1 columns instead of 2)
#     Line #412 (got 11 columns instead of 2)
#     Line #413 (got 1 columns instead of 2)
#     Line #415 (got 14 columns instead of 2)
#     Line #416 (got 59 columns instead of 2)
#     Line #417 (got 1 columns instead of 2)
#     Line #418 (got 1 columns instead of 2)
#     Line #420 (got 1 columns instead of 2)
#     Line #421 (got 11 columns instead of 2)
#     Line #424 (got 14 columns instead of 2)
#     Line #425 (got 59 columns instead of 2)
#     Line #426 (got 1 columns instead of 2)
#     Line #427 (got 1 columns instead of 2)
#     Line #429 (got 1 columns instead of 2)
#     Line #430 (got 11 columns instead of 2)
#     Line #431 (got 1 columns instead of 2)
#     Line #433 (got 14 columns instead of 2)
#     Line #434 (got 59 columns instead of 2)
#     Line #435 (got 1 columns instead of 2)
#     Line #436 (got 1 columns instead of 2)
#     Line #438 (got 1 columns instead of 2)
#     Line #439 (got 1 columns instead of 2)
#     Line #440 (got 1 columns instead of 2)
#     Line #441 (got 1 columns instead of 2)
#     Line #442 (got 1 columns instead of 2)
#     Line #444 (got 12 columns instead of 2)
#     Line #445 (got 15 columns instead of 2)
#     Line #446 (got 1 columns instead of 2)
#     Line #447 (got 15 columns instead of 2)
#     Line #448 (got 24 columns instead of 2)
#     Line #449 (got 1 columns instead of 2)
#     Line #450 (got 1 columns instead of 2)
#     Line #451 (got 15 columns instead of 2)
#     Line #452 (got 7 columns instead of 2)
#     Line #453 (got 8 columns instead of 2)
#     Line #454 (got 8 columns instead of 2)
#     Line #455 (got 4 columns instead of 2)
#     Line #456 (got 1 columns instead of 2)
#     Line #457 (got 9 columns instead of 2)
#     Line #458 (got 1 columns instead of 2)
#     Line #461 (got 1 columns instead of 2)
#     Line #463 (got 1 columns instead of 2)
#     Line #464 (got 9 columns instead of 2)
#     Line #465 (got 4 columns instead of 2)
#     Line #468 (got 1 columns instead of 2)
#     Line #470 (got 1 columns instead of 2)
#     Line #471 (got 9 columns instead of 2)
#     Line #472 (got 1 columns instead of 2)
#     Line #475 (got 1 columns instead of 2)
#     Line #477 (got 1 columns instead of 2)
#     Line #478 (got 9 columns instead of 2)
#     Line #479 (got 1 columns instead of 2)
#     Line #482 (got 1 columns instead of 2)
#     Line #484 (got 1 columns instead of 2)
#     Line #485 (got 1 columns instead of 2)
#     Line #486 (got 5 columns instead of 2)
#     Line #487 (got 8 columns instead of 2)
#     Line #488 (got 4 columns instead of 2)
#     Line #489 (got 1 columns instead of 2)
#     Line #490 (got 9 columns instead of 2)
#     Line #491 (got 1 columns instead of 2)
#     Line #494 (got 1 columns instead of 2)
#     Line #496 (got 1 columns instead of 2)
#     Line #497 (got 9 columns instead of 2)
#     Line #498 (got 1 columns instead of 2)
#     Line #501 (got 1 columns instead of 2)
#     Line #503 (got 1 columns instead of 2)
#     Line #504 (got 9 columns instead of 2)
#     Line #505 (got 1 columns instead of 2)
#     Line #508 (got 1 columns instead of 2)
#     Line #510 (got 1 columns instead of 2)
#     Line #511 (got 9 columns instead of 2)
#     Line #512 (got 4 columns instead of 2)
#     Line #515 (got 1 columns instead of 2)
#     Line #517 (got 1 columns instead of 2)
#     Line #518 (got 1 columns instead of 2)
#     Line #519 (got 1 columns instead of 2)
#     Line #520 (got 3 columns instead of 2)
#     Line #521 (got 5 columns instead of 2)
#     Line #522 (got 7 columns instead of 2)
#     Line #523 (got 4 columns instead of 2)
#     Line #524 (got 1 columns instead of 2)
#     Line #525 (got 9 columns instead of 2)
#     Line #526 (got 1 columns instead of 2)
#     Line #529 (got 1 columns instead of 2)
#     Line #531 (got 1 columns instead of 2)
#     Line #532 (got 9 columns instead of 2)
#     Line #536 (got 1 columns instead of 2)
#     Line #538 (got 1 columns instead of 2)
#     Line #539 (got 9 columns instead of 2)
#     Line #540 (got 1 columns instead of 2)
#     Line #543 (got 1 columns instead of 2)
#     Line #545 (got 1 columns instead of 2)
#     Line #546 (got 9 columns instead of 2)
#     Line #547 (got 1 columns instead of 2)
#     Line #550 (got 1 columns instead of 2)
#     Line #552 (got 1 columns instead of 2)
#     Line #553 (got 9 columns instead of 2)
#     Line #554 (got 3 columns instead of 2)
#     Line #557 (got 1 columns instead of 2)
#     Line #559 (got 1 columns instead of 2)
#     Line #560 (got 1 columns instead of 2)
#     Line #561 (got 1 columns instead of 2)
#     Line #562 (got 10 columns instead of 2)
#     Line #564 (got 3 columns instead of 2)
#     Line #565 (got 13 columns instead of 2)
#     Line #566 (got 28 columns instead of 2)
#     Line #567 (got 1 columns instead of 2)
#     Line #569 (got 1 columns instead of 2)
#     Line #570 (got 1 columns instead of 2)
#     Line #572 (got 12 columns instead of 2)
#     Line #573 (got 15 columns instead of 2)
#     Line #574 (got 1 columns instead of 2)
#     Line #575 (got 15 columns instead of 2)
#     Line #576 (got 24 columns instead of 2)
#     Line #577 (got 1 columns instead of 2)
#     Line #578 (got 1 columns instead of 2)
#     Line #579 (got 17 columns instead of 2)
#     Line #580 (got 7 columns instead of 2)
#     Line #581 (got 5 columns instead of 2)
#     Line #582 (got 6 columns instead of 2)
#     Line #583 (got 4 columns instead of 2)
#     Line #584 (got 1 columns instead of 2)
#     Line #585 (got 9 columns instead of 2)
#     Line #586 (got 1 columns instead of 2)
#     Line #589 (got 1 columns instead of 2)
#     Line #591 (got 1 columns instead of 2)
#     Line #592 (got 9 columns instead of 2)
#     Line #593 (got 1 columns instead of 2)
#     Line #596 (got 1 columns instead of 2)
#     Line #598 (got 1 columns instead of 2)
#     Line #599 (got 9 columns instead of 2)
#     Line #600 (got 1 columns instead of 2)
#     Line #603 (got 1 columns instead of 2)
#     Line #605 (got 1 columns instead of 2)
#     Line #606 (got 9 columns instead of 2)
#     Line #610 (got 1 columns instead of 2)
#     Line #612 (got 1 columns instead of 2)
#     Line #613 (got 9 columns instead of 2)
#     Line #617 (got 1 columns instead of 2)
#     Line #619 (got 1 columns instead of 2)
#     Line #620 (got 1 columns instead of 2)
#     Line #621 (got 1 columns instead of 2)
#     Line #622 (got 3 columns instead of 2)
#     Line #623 (got 6 columns instead of 2)
#     Line #624 (got 6 columns instead of 2)
#     Line #625 (got 4 columns instead of 2)
#     Line #626 (got 1 columns instead of 2)
#     Line #627 (got 11 columns instead of 2)
#     Line #630 (got 14 columns instead of 2)
#     Line #631 (got 59 columns instead of 2)
#     Line #632 (got 1 columns instead of 2)
#     Line #633 (got 1 columns instead of 2)
#     Line #635 (got 1 columns instead of 2)
#     Line #636 (got 11 columns instead of 2)
#     Line #637 (got 4 columns instead of 2)
#     Line #639 (got 14 columns instead of 2)
#     Line #640 (got 59 columns instead of 2)
#     Line #641 (got 1 columns instead of 2)
#     Line #642 (got 1 columns instead of 2)
#     Line #644 (got 1 columns instead of 2)
#     Line #645 (got 9 columns instead of 2)
#     Line #649 (got 1 columns instead of 2)
#     Line #651 (got 1 columns instead of 2)
#     Line #652 (got 11 columns instead of 2)
#     Line #653 (got 1 columns instead of 2)
#     Line #655 (got 14 columns instead of 2)
#     Line #656 (got 59 columns instead of 2)
#     Line #657 (got 1 columns instead of 2)
#     Line #658 (got 1 columns instead of 2)
#     Line #660 (got 1 columns instead of 2)
#     Line #661 (got 9 columns instead of 2)
#     Line #665 (got 1 columns instead of 2)
#     Line #667 (got 1 columns instead of 2)
#     Line #668 (got 1 columns instead of 2)
#     Line #669 (got 1 columns instead of 2)
#     Line #670 (got 1 columns instead of 2)
#     Line #671 (got 1 columns instead of 2)
#     Line #674 (got 12 columns instead of 2)
#     Line #675 (got 15 columns instead of 2)
#     Line #677 (got 15 columns instead of 2)
#     Line #678 (got 24 columns instead of 2)
#     Line #679 (got 1 columns instead of 2)
#     Line #680 (got 1 columns instead of 2)
#     Line #681 (got 15 columns instead of 2)
#     Line #683 (got 8 columns instead of 2)
#     Line #684 (got 4 columns instead of 2)
#     Line #685 (got 1 columns instead of 2)
#     Line #686 (got 12 columns instead of 2)
#     Line #688 (got 1 columns instead of 2)
#     Line #689 (got 4 columns instead of 2)
#     Line #690 (got 4 columns instead of 2)
#     Line #691 (got 1 columns instead of 2)
#     Line #694 (got 1 columns instead of 2)
#     Line #696 (got 1 columns instead of 2)
#     Line #697 (got 1 columns instead of 2)
#     Line #698 (got 8 columns instead of 2)
#     Line #699 (got 4 columns instead of 2)
#     Line #700 (got 1 columns instead of 2)
#     Line #701 (got 12 columns instead of 2)
#     Line #703 (got 1 columns instead of 2)
#     Line #704 (got 5 columns instead of 2)
#     Line #705 (got 3 columns instead of 2)
#     Line #706 (got 1 columns instead of 2)
#     Line #709 (got 1 columns instead of 2)
#     Line #711 (got 1 columns instead of 2)
#     Line #712 (got 1 columns instead of 2)
#     Line #713 (got 5 columns instead of 2)
#     Line #714 (got 6 columns instead of 2)
#     Line #715 (got 4 columns instead of 2)
#     Line #716 (got 1 columns instead of 2)
#     Line #717 (got 9 columns instead of 2)
#     Line #718 (got 1 columns instead of 2)
#     Line #721 (got 1 columns instead of 2)
#     Line #723 (got 1 columns instead of 2)
#     Line #724 (got 9 columns instead of 2)
#     Line #725 (got 1 columns instead of 2)
#     Line #728 (got 1 columns instead of 2)
#     Line #730 (got 1 columns instead of 2)
#     Line #731 (got 9 columns instead of 2)
#     Line #732 (got 1 columns instead of 2)
#     Line #735 (got 1 columns instead of 2)
#     Line #737 (got 1 columns instead of 2)
#     Line #738 (got 1 columns instead of 2)
#     Line #739 (got 1 columns instead of 2)
#     Line #740 (got 1 columns instead of 2)
#     Line #741 (got 1 columns instead of 2)
#     Line #744 (got 12 columns instead of 2)
#     Line #745 (got 15 columns instead of 2)
#     Line #746 (got 1 columns instead of 2)
#     Line #747 (got 15 columns instead of 2)
#     Line #748 (got 24 columns instead of 2)
#     Line #749 (got 1 columns instead of 2)
#     Line #750 (got 1 columns instead of 2)
#     Line #751 (got 15 columns instead of 2)
#     Line #753 (got 8 columns instead of 2)
#     Line #754 (got 4 columns instead of 2)
#     Line #755 (got 1 columns instead of 2)
#     Line #756 (got 12 columns instead of 2)
#     Line #757 (got 14 columns instead of 2)
#     Line #758 (got 101 columns instead of 2)
#     Line #759 (got 1 columns instead of 2)
#     Line #760 (got 1 columns instead of 2)
#     Line #761 (got 4 columns instead of 2)
#     Line #762 (got 3 columns instead of 2)
#     Line #763 (got 1 columns instead of 2)
#     Line #766 (got 1 columns instead of 2)
#     Line #768 (got 1 columns instead of 2)
#     Line #769 (got 1 columns instead of 2)
#     Line #770 (got 5 columns instead of 2)
#     Line #771 (got 7 columns instead of 2)
#     Line #772 (got 4 columns instead of 2)
#     Line #773 (got 1 columns instead of 2)
#     Line #774 (got 13 columns instead of 2)
#     Line #775 (got 14 columns instead of 2)
#     Line #776 (got 73 columns instead of 2)
#     Line #777 (got 1 columns instead of 2)
#     Line #778 (got 1 columns instead of 2)
#     Line #779 (got 4 columns instead of 2)
#     Line #780 (got 3 columns instead of 2)
#     Line #781 (got 1 columns instead of 2)
#     Line #784 (got 1 columns instead of 2)
#     Line #786 (got 1 columns instead of 2)
#     Line #787 (got 13 columns instead of 2)
#     Line #788 (got 14 columns instead of 2)
#     Line #789 (got 147 columns instead of 2)
#     Line #790 (got 1 columns instead of 2)
#     Line #791 (got 1 columns instead of 2)
#     Line #792 (got 4 columns instead of 2)
#     Line #793 (got 3 columns instead of 2)
#     Line #794 (got 1 columns instead of 2)
#     Line #797 (got 1 columns instead of 2)
#     Line #799 (got 1 columns instead of 2)
#     Line #800 (got 12 columns instead of 2)
#     Line #801 (got 14 columns instead of 2)
#     Line #802 (got 100 columns instead of 2)
#     Line #803 (got 1 columns instead of 2)
#     Line #804 (got 1 columns instead of 2)
#     Line #805 (got 4 columns instead of 2)
#     Line #806 (got 3 columns instead of 2)
#     Line #807 (got 1 columns instead of 2)
#     Line #810 (got 1 columns instead of 2)
#     Line #812 (got 1 columns instead of 2)
#     Line #813 (got 1 columns instead of 2)
#     Line #814 (got 1 columns instead of 2)
#     Line #815 (got 1 columns instead of 2)
#     Line #816 (got 1 columns instead of 2)
#     Line #819 (got 12 columns instead of 2)
#     Line #820 (got 11 columns instead of 2)
#     Line #821 (got 1 columns instead of 2)
#     Line #823 (got 1 columns instead of 2)
#     Line #824 (got 1 columns instead of 2)
#     Line #826 (got 12 columns instead of 2)
#     Line #830 (got 17 columns instead of 2)
#     Line #831 (got 1 columns instead of 2)
#     Line #832 (got 8 columns instead of 2)
#     Line #833 (got 1 columns instead of 2)
#     Line #834 (got 1 columns instead of 2)
#     Line #835 (got 1 columns instead of 2)
#     Line #836 (got 1 columns instead of 2)
#     Line #837 (got 16 columns instead of 2)
#     Line #838 (got 1 columns instead of 2)
#     Line #839 (got 4 columns instead of 2)
#     Line #840 (got 1 columns instead of 2)
#     Line #841 (got 4 columns instead of 2)
#     Line #842 (got 1 columns instead of 2)
#     Line #843 (got 1 columns instead of 2)
#     Line #844 (got 1 columns instead of 2)
#     Line #845 (got 1 columns instead of 2)
#     Line #846 (got 1 columns instead of 2)
#     Line #847 (got 3 columns instead of 2)
#     Line #848 (got 12 columns instead of 2)
#     Line #849 (got 34 columns instead of 2)
#     Line #850 (got 1 columns instead of 2)
#     Line #851 (got 1 columns instead of 2)
#     Line #852 (got 6 columns instead of 2)
#     Line #853 (got 3 columns instead of 2)
#     Line #854 (got 8 columns instead of 2)
#     Line #856 (got 1 columns instead of 2)
#     Line #857 (got 1 columns instead of 2)
#     Line #859 (got 4 columns instead of 2)
#     Line #862 (got 4 columns instead of 2)
#     Line #864 (got 9 columns instead of 2)
#     Line #865 (got 3 columns instead of 2)
#     Line #867 (got 14 columns instead of 2)
#     Line #869 (got 1 columns instead of 2)
#     Line #870 (got 1 columns instead of 2)
#     Line #871 (got 1 columns instead of 2)
#     Line #872 (got 9 columns instead of 2)
#     Line #873 (got 7 columns instead of 2)
#     Line #874 (got 3 columns instead of 2)
#     Line #875 (got 5 columns instead of 2)
#     Line #876 (got 1 columns instead of 2)
#     Line #877 (got 1 columns instead of 2)
#     Line #878 (got 1 columns instead of 2)
#     Line #879 (got 3 columns instead of 2)
#     Line #880 (got 1 columns instead of 2)
#     Line #881 (got 1 columns instead of 2)
#     Line #882 (got 4 columns instead of 2)
#     Line #883 (got 13 columns instead of 2)
#     Line #884 (got 34 columns instead of 2)
#     Line #885 (got 1 columns instead of 2)
#     Line #886 (got 1 columns instead of 2)
#     Line #887 (got 3 columns instead of 2)
#     Line #888 (got 1 columns instead of 2)
#     Line #889 (got 1 columns instead of 2)
#     Line #890 (got 1 columns instead of 2)
#     Line #891 (got 1 columns instead of 2)
#     Line #892 (got 1 columns instead of 2)
#     Line #894 (got 4 columns instead of 2)
#     Line #895 (got 12 columns instead of 2)
#     Line #896 (got 1 columns instead of 2)
#     Line #897 (got 1 columns instead of 2)
#     Line #898 (got 1 columns instead of 2)
#     Line #899 (got 1 columns instead of 2)
#     Line #900 (got 6 columns instead of 2)
#     Line #901 (got 1 columns instead of 2)
#     Line #902 (got 1 columns instead of 2)
#     Line #903 (got 3 columns instead of 2)
#     Line #904 (got 7 columns instead of 2)
#     Line #905 (got 1 columns instead of 2)
#     Line #906 (got 1 columns instead of 2)
#     Line #907 (got 1 columns instead of 2)
#     Line #908 (got 29 columns instead of 2)
#     Line #909 (got 53 columns instead of 2)
#     Line #910 (got 1 columns instead of 2)
#     Line #911 (got 1 columns instead of 2)
#     Line #913 (got 1 columns instead of 2)
#     Line #915 (got 12 columns instead of 2)
#     Line #916 (got 34 columns instead of 2)
#     Line #917 (got 1 columns instead of 2)
#     Line #918 (got 1 columns instead of 2)
#     Line #921 (got 12 columns instead of 2)
#     Line #922 (got 51 columns instead of 2)
#     Line #923 (got 1 columns instead of 2)
#     Line #924 (got 1 columns instead of 2)
#     Line #927 (got 12 columns instead of 2)
#     Line #928 (got 89 columns instead of 2)
#     Line #929 (got 1 columns instead of 2)
#     Line #930 (got 1 columns instead of 2)
#     Line #933 (got 12 columns instead of 2)
#     Line #934 (got 54 columns instead of 2)
#     Line #935 (got 1 columns instead of 2)
#     Line #936 (got 1 columns instead of 2)
#     Line #939 (got 12 columns instead of 2)
#     Line #940 (got 66 columns instead of 2)
#     Line #941 (got 1 columns instead of 2)
#     Line #942 (got 1 columns instead of 2)
#     Line #945 (got 12 columns instead of 2)
#     Line #946 (got 34 columns instead of 2)
#     Line #947 (got 1 columns instead of 2)
#     Line #948 (got 1 columns instead of 2)
#     Line #951 (got 12 columns instead of 2)
#     Line #952 (got 46 columns instead of 2)
#     Line #953 (got 1 columns instead of 2)
#     Line #954 (got 1 columns instead of 2)
#     Line #957 (got 12 columns instead of 2)
#     Line #958 (got 15 columns instead of 2)
#     Line #959 (got 1 columns instead of 2)
#     Line #960 (got 1 columns instead of 2)
#     Line #963 (got 12 columns instead of 2)
#     Line #964 (got 58 columns instead of 2)
#     Line #965 (got 1 columns instead of 2)
#     Line #966 (got 1 columns instead of 2)
#     Line #969 (got 12 columns instead of 2)
#     Line #970 (got 96 columns instead of 2)
#     Line #971 (got 1 columns instead of 2)
#     Line #972 (got 1 columns instead of 2)
#     Line #975 (got 12 columns instead of 2)
#     Line #976 (got 72 columns instead of 2)
#     Line #977 (got 1 columns instead of 2)
#     Line #978 (got 1 columns instead of 2)
#     Line #981 (got 12 columns instead of 2)
#     Line #982 (got 43 columns instead of 2)
#     Line #983 (got 1 columns instead of 2)
#     Line #984 (got 1 columns instead of 2)
#     Line #987 (got 12 columns instead of 2)
#     Line #988 (got 90 columns instead of 2)
#     Line #989 (got 1 columns instead of 2)
#     Line #990 (got 1 columns instead of 2)
#     Line #993 (got 12 columns instead of 2)
#     Line #994 (got 82 columns instead of 2)
#     Line #995 (got 1 columns instead of 2)
#     Line #996 (got 1 columns instead of 2)
#     Line #999 (got 12 columns instead of 2)
#     Line #1000 (got 80 columns instead of 2)
#     Line #1001 (got 1 columns instead of 2)
#     Line #1002 (got 1 columns instead of 2)
#     Line #1005 (got 12 columns instead of 2)
#     Line #1006 (got 66 columns instead of 2)
#     Line #1007 (got 1 columns instead of 2)
#     Line #1008 (got 1 columns instead of 2)
#     Line #1011 (got 12 columns instead of 2)
#     Line #1012 (got 100 columns instead of 2)
#     Line #1013 (got 1 columns instead of 2)
#     Line #1014 (got 1 columns instead of 2)
#     Line #1017 (got 12 columns instead of 2)
#     Line #1018 (got 91 columns instead of 2)
#     Line #1019 (got 1 columns instead of 2)
#     Line #1020 (got 1 columns instead of 2)
#     Line #1023 (got 12 columns instead of 2)
#     Line #1024 (got 50 columns instead of 2)
#     Line #1025 (got 1 columns instead of 2)
#     Line #1026 (got 1 columns instead of 2)
#     Line #1029 (got 12 columns instead of 2)
#     Line #1030 (got 91 columns instead of 2)
#     Line #1031 (got 1 columns instead of 2)
#     Line #1032 (got 1 columns instead of 2)
#     Line #1035 (got 12 columns instead of 2)
#     Line #1036 (got 143 columns instead of 2)
#     Line #1037 (got 1 columns instead of 2)
#     Line #1038 (got 1 columns instead of 2)
#     Line #1041 (got 12 columns instead of 2)
#     Line #1042 (got 110 columns instead of 2)
#     Line #1043 (got 1 columns instead of 2)
#     Line #1044 (got 1 columns instead of 2)
#     Line #1047 (got 12 columns instead of 2)
#     Line #1048 (got 94 columns instead of 2)
#     Line #1049 (got 1 columns instead of 2)
#     Line #1050 (got 1 columns instead of 2)
#     Line #1053 (got 12 columns instead of 2)
#     Line #1054 (got 90 columns instead of 2)
#     Line #1055 (got 1 columns instead of 2)
#     Line #1056 (got 1 columns instead of 2)
#     Line #1059 (got 12 columns instead of 2)
#     Line #1060 (got 106 columns instead of 2)
#     Line #1061 (got 1 columns instead of 2)
#     Line #1062 (got 1 columns instead of 2)
#     Line #1065 (got 12 columns instead of 2)
#     Line #1066 (got 75 columns instead of 2)
#     Line #1067 (got 1 columns instead of 2)
#     Line #1068 (got 1 columns instead of 2)
#     Line #1071 (got 12 columns instead of 2)
#     Line #1072 (got 42 columns instead of 2)
#     Line #1073 (got 1 columns instead of 2)
#     Line #1074 (got 1 columns instead of 2)
#     Line #1077 (got 12 columns instead of 2)
#     Line #1078 (got 50 columns instead of 2)
#     Line #1079 (got 1 columns instead of 2)
#     Line #1080 (got 1 columns instead of 2)
#     Line #1083 (got 12 columns instead of 2)
#     Line #1084 (got 45 columns instead of 2)
#     Line #1085 (got 1 columns instead of 2)
#     Line #1086 (got 1 columns instead of 2)
#     Line #1089 (got 12 columns instead of 2)
#     Line #1090 (got 46 columns instead of 2)
#     Line #1091 (got 1 columns instead of 2)
#     Line #1092 (got 1 columns instead of 2)
#     Line #1095 (got 12 columns instead of 2)
#     Line #1096 (got 45 columns instead of 2)
#     Line #1097 (got 1 columns instead of 2)
#     Line #1098 (got 1 columns instead of 2)
#     Line #1101 (got 12 columns instead of 2)
#     Line #1102 (got 86 columns instead of 2)
#     Line #1103 (got 1 columns instead of 2)
#     Line #1104 (got 1 columns instead of 2)
#     Line #1107 (got 12 columns instead of 2)
#     Line #1108 (got 86 columns instead of 2)
#     Line #1109 (got 1 columns instead of 2)
#     Line #1110 (got 1 columns instead of 2)
#     Line #1113 (got 12 columns instead of 2)
#     Line #1114 (got 59 columns instead of 2)
#     Line #1115 (got 1 columns instead of 2)
#     Line #1116 (got 1 columns instead of 2)
#     Line #1119 (got 1 columns instead of 2)
#     Line #1120 (got 1 columns instead of 2)
#     Line #1122 (got 1 columns instead of 2)
#     Line #1123 (got 1 columns instead of 2)
#     Line #1124 (got 1 columns instead of 2)
#     Line #1125 (got 1 columns instead of 2)
#     Line #1126 (got 1 columns instead of 2)
#     Line #1127 (got 1 columns instead of 2)
#     Line #1128 (got 1 columns instead of 2)
#     Line #1129 (got 1 columns instead of 2)
#     Line #1130 (got 1 columns instead of 2)
#     Line #1131 (got 1 columns instead of 2)
#     Line #1132 (got 4 columns instead of 2)
#     Line #1134 (got 12 columns instead of 2)
#     Line #1135 (got 31 columns instead of 2)
#     Line #1136 (got 1 columns instead of 2)
#     Line #1137 (got 1 columns instead of 2)
#     Line #1138 (got 1 columns instead of 2)
#     Line #1140 (got 5 columns instead of 2)
#     Line #1141 (got 1 columns instead of 2)
#     Line #1142 (got 8 columns instead of 2)
#     Line #1143 (got 13 columns instead of 2)
#     Line #1144 (got 1 columns instead of 2)
#     Line #1145 (got 1 columns instead of 2)
#     Line #1146 (got 1 columns instead of 2)
#     Line #1148 (got 1 columns instead of 2)
#     Line #1149 (got 1 columns instead of 2)
#     Line #1150 (got 1 columns instead of 2)
#     Line #1154 (got 1 columns instead of 2)
#     Line #1155 (got 3 columns instead of 2)
#     Line #1156 (got 3 columns instead of 2)
#     Line #1159 (got 4 columns instead of 2)
#     Line #1161 (got 1 columns instead of 2)
#     Line #1163 (got 1 columns instead of 2)
#     Line #1165 (got 18 columns instead of 2)
#     Line #1166 (got 40 columns instead of 2)
#     Line #1167 (got 1 columns instead of 2)
#     Line #1168 (got 1 columns instead of 2)
#     Line #1169 (got 1 columns instead of 2)
#     Line #1171 (got 1 columns instead of 2)
#     Line #1173 (got 18 columns instead of 2)
#     Line #1174 (got 12 columns instead of 2)
#     Line #1175 (got 8 columns instead of 2)
#     Line #1176 (got 15 columns instead of 2)
#     Line #1177 (got 12 columns instead of 2)
#     Line #1178 (got 1 columns instead of 2)
#     Line #1179 (got 1 columns instead of 2)
#     Line #1180 (got 10 columns instead of 2)
#     Line #1181 (got 1 columns instead of 2)
#     Line #1182 (got 3 columns instead of 2)
#     Line #1183 (got 1 columns instead of 2)
#     Line #1184 (got 1 columns instead of 2)
#     Line #1185 (got 1 columns instead of 2)
#     Line #1189 (got 1 columns instead of 2)
#     Line #1190 (got 3 columns instead of 2)
#     Line #1191 (got 4 columns instead of 2)
#     Line #1194 (got 4 columns instead of 2)
#     Line #1196 (got 1 columns instead of 2)
#     Line #1197 (got 11 columns instead of 2)
#     Line #1198 (got 1 columns instead of 2)
#     Line #1200 (got 18 columns instead of 2)
#     Line #1201 (got 40 columns instead of 2)
#     Line #1202 (got 1 columns instead of 2)
#     Line #1203 (got 1 columns instead of 2)
#     Line #1204 (got 1 columns instead of 2)
#     Line #1206 (got 1 columns instead of 2)
#     Line #1208 (got 5 columns instead of 2)
#     Line #1210 (got 4 columns instead of 2)
#     Line #1211 (got 15 columns instead of 2)
#     Line #1214 (got 5 columns instead of 2)
#     Line #1218 (got 4 columns instead of 2)
#     Line #1219 (got 1 columns instead of 2)
#     Line #1220 (got 1 columns instead of 2)
#     Line #1221 (got 1 columns instead of 2)
#     Line #1222 (got 1 columns instead of 2)
#     Line #1223 (got 1 columns instead of 2)
#     Line #1224 (got 1 columns instead of 2)
#     Line #1225 (got 1 columns instead of 2)
#     Line #1226 (got 1 columns instead of 2)
#     Line #1227 (got 1 columns instead of 2)
#     Line #1228 (got 1 columns instead of 2)
#     Line #1229 (got 5 columns instead of 2)
#     Line #1230 (got 1 columns instead of 2)
#     Line #1231 (got 1 columns instead of 2)
#     Line #1235 (got 1 columns instead of 2)
#     Line #1236 (got 1 columns instead of 2)
#     Line #1237 (got 1 columns instead of 2)
#     Line #1238 (got 1 columns instead of 2)
#     Line #1239 (got 1 columns instead of 2)
#     Line #1240 (got 1 columns instead of 2)
#     Line #1241 (got 1 columns instead of 2)
#     Line #1242 (got 5 columns instead of 2)
#     Line #1243 (got 1 columns instead of 2)
#     Line #1244 (got 1 columns instead of 2)
#     Line #1245 (got 1 columns instead of 2)
#     Line #1247 (got 3 columns instead of 2)
#     Line #1248 (got 10 columns instead of 2)
#     Line #1249 (got 1 columns instead of 2)
#     Line #1254 (got 1 columns instead of 2)
#     Line #1256 (got 1 columns instead of 2)
#     Line #1257 (got 1 columns instead of 2)
#     Line #1258 (got 7 columns instead of 2)
#     Line #1259 (got 1 columns instead of 2)
#     Line #1260 (got 3 columns instead of 2)
#     Line #1261 (got 1 columns instead of 2)
#     Line #1262 (got 1 columns instead of 2)
#     Line #1263 (got 1 columns instead of 2)
#     Line #1264 (got 1 columns instead of 2)
#     Line #1265 (got 1 columns instead of 2)
#     Line #1266 (got 1 columns instead of 2)
#     Line #1269 (got 4 columns instead of 2)
#     Line #1270 (got 1 columns instead of 2)
#     Line #1271 (got 1 columns instead of 2)
#     Line #1272 (got 13 columns instead of 2)
#     Line #1274 (got 4 columns instead of 2)
#     Line #1275 (got 7 columns instead of 2)
#     Line #1276 (got 1 columns instead of 2)
#     Line #1278 (got 1 columns instead of 2)
#     Line #1279 (got 1 columns instead of 2)
#     Line #1282 (got 12 columns instead of 2)
#     Line #1283 (got 4 columns instead of 2)
#     Line #1284 (got 10 columns instead of 2)
#     Line #1285 (got 1 columns instead of 2)
#     Line #1287 (got 1 columns instead of 2)
#     Line #1288 (got 7 columns instead of 2)
#     Line #1289 (got 1 columns instead of 2)
#     Line #1290 (got 1 columns instead of 2)
#     Line #1291 (got 1 columns instead of 2)
#     Line #1292 (got 1 columns instead of 2)
#     Line #1293 (got 1 columns instead of 2)
#     Line #1295 (got 8 columns instead of 2)
#     Line #1297 (got 12 columns instead of 2)
#     Line #1298 (got 53 columns instead of 2)
#     Line #1299 (got 1 columns instead of 2)
#     Line #1300 (got 17 columns instead of 2)
#     Line #1301 (got 17 columns instead of 2)
#     Line #1302 (got 17 columns instead of 2)
#     Line #1304 (got 24 columns instead of 2)
#     Line #1305 (got 40 columns instead of 2)
#     Line #1306 (got 1 columns instead of 2)
#     Line #1307 (got 10 columns instead of 2)
#     Line #1311 (got 1 columns instead of 2)
#     Line #1312 (got 1 columns instead of 2)
#     Line #1314 (got 3 columns instead of 2)
#     Line #1323 (got 4 columns instead of 2)
#     Line #1330 (got 6 columns instead of 2)
#     Line #1332 (got 8 columns instead of 2)
#     Line #1333 (got 12 columns instead of 2)
#     Line #1334 (got 40 columns instead of 2)
#     Line #1335 (got 1 columns instead of 2)
#     Line #1336 (got 1 columns instead of 2)
#     Line #1337 (got 4 columns instead of 2)
#     Line #1339 (got 3 columns instead of 2)
#     Line #1341 (got 1 columns instead of 2)
#     Line #1342 (got 1 columns instead of 2)
#     Line #1343 (got 1 columns instead of 2)
#     Line #1344 (got 1 columns instead of 2)
#     Line #1345 (got 1 columns instead of 2)
#     Line #1355 (got 1 columns instead of 2)
#     Line #1357 (got 1 columns instead of 2)
#     Line #1358 (got 1 columns instead of 2)
#     Line #1359 (got 1 columns instead of 2)
#     Line #1360 (got 1 columns instead of 2)
#     Line #1361 (got 1 columns instead of 2)
#     Line #1362 (got 4 columns instead of 2)
#     Line #1363 (got 3 columns instead of 2)
#     Line #1373 (got 8 columns instead of 2)
#     Line #1375 (got 9 columns instead of 2)
#     Line #1377 (got 4 columns instead of 2)
#     Line #1379 (got 8 columns instead of 2)
#     Line #1380 (got 14 columns instead of 2)
#     Line #1381 (got 66 columns instead of 2)
#     Line #1382 (got 1 columns instead of 2)
#     Line #1384 (got 4 columns instead of 2)
#     Line #1385 (got 9 columns instead of 2)
#     Line #1386 (got 1 columns instead of 2)
#     Line #1388 (got 4 columns instead of 2)
#     Line #1389 (got 4 columns instead of 2)
#     Line #1391 (got 1 columns instead of 2)
#     Line #1393 (got 5 columns instead of 2)
#     Line #1394 (got 1 columns instead of 2)
#     Line #1397 (got 1 columns instead of 2)
#     Line #1399 (got 6 columns instead of 2)
#     Line #1400 (got 8 columns instead of 2)
#     Line #1404 (got 1 columns instead of 2)
#     Line #1405 (got 34 columns instead of 2)
#     Line #1406 (got 64 columns instead of 2)
#     Line #1407 (got 1 columns instead of 2)
#     Line #1408 (got 18 columns instead of 2)
#     Line #1410 (got 1 columns instead of 2)
#     Line #1412 (got 1 columns instead of 2)
#     Line #1413 (got 26 columns instead of 2)
#     Line #1414 (got 67 columns instead of 2)
#     Line #1415 (got 1 columns instead of 2)
#     Line #1416 (got 7 columns instead of 2)
#     Line #1417 (got 1 columns instead of 2)
#     Line #1418 (got 1 columns instead of 2)
#     Line #1420 (got 1 columns instead of 2)
#     Line #1421 (got 4 columns instead of 2)
#     Line #1422 (got 35 columns instead of 2)
#     Line #1423 (got 61 columns instead of 2)
#     Line #1424 (got 3 columns instead of 2)
#     Line #1425 (got 1 columns instead of 2)
#     Line #1426 (got 21 columns instead of 2)
#     Line #1427 (got 1 columns instead of 2)
#     Line #1428 (got 1 columns instead of 2)
#     Line #1430 (got 1 columns instead of 2)
#     Line #1432 (got 1 columns instead of 2)
#     Line #1433 (got 1 columns instead of 2)
#     Line #1435 (got 3 columns instead of 2)
#     Line #1436 (got 1 columns instead of 2)
#     Line #1441 (got 4 columns instead of 2)
#     Line #1442 (got 3 columns instead of 2)
#     Line #1443 (got 15 columns instead of 2)
#     Line #1445 (got 15 columns instead of 2)
#     Line #1446 (got 51 columns instead of 2)
#     Line #1447 (got 1 columns instead of 2)
#     Line #1449 (got 8 columns instead of 2)
#     Line #1453 (got 1 columns instead of 2)
#     Line #1454 (got 3 columns instead of 2)
#     Line #1455 (got 9 columns instead of 2)
#     Line #1457 (got 15 columns instead of 2)
#     Line #1458 (got 42 columns instead of 2)
#     Line #1459 (got 1 columns instead of 2)
#     Line #1461 (got 8 columns instead of 2)
#     Line #1465 (got 1 columns instead of 2)
#     Line #1466 (got 3 columns instead of 2)
#     Line #1467 (got 8 columns instead of 2)
#     Line #1469 (got 15 columns instead of 2)
#     Line #1470 (got 78 columns instead of 2)
#     Line #1471 (got 1 columns instead of 2)
#     Line #1472 (got 4 columns instead of 2)
#     Line #1473 (got 8 columns instead of 2)
#     Line #1477 (got 1 columns instead of 2)
#     Line #1478 (got 3 columns instead of 2)
#     Line #1479 (got 7 columns instead of 2)
#     Line #1481 (got 15 columns instead of 2)
#     Line #1482 (got 45 columns instead of 2)
#     Line #1483 (got 1 columns instead of 2)
#     Line #1485 (got 8 columns instead of 2)
#     Line #1489 (got 1 columns instead of 2)
#     Line #1490 (got 3 columns instead of 2)
#     Line #1491 (got 9 columns instead of 2)
#     Line #1493 (got 15 columns instead of 2)
#     Line #1494 (got 38 columns instead of 2)
#     Line #1495 (got 1 columns instead of 2)
#     Line #1497 (got 8 columns instead of 2)
#     Line #1501 (got 1 columns instead of 2)
#     Line #1502 (got 3 columns instead of 2)
#     Line #1503 (got 12 columns instead of 2)
#     Line #1505 (got 15 columns instead of 2)
#     Line #1506 (got 92 columns instead of 2)
#     Line #1507 (got 1 columns instead of 2)
#     Line #1509 (got 3 columns instead of 2)
#     Line #1512 (got 1 columns instead of 2)
#     Line #1513 (got 3 columns instead of 2)
#     Line #1514 (got 13 columns instead of 2)
#     Line #1516 (got 15 columns instead of 2)
#     Line #1517 (got 46 columns instead of 2)
#     Line #1518 (got 1 columns instead of 2)
#     Line #1520 (got 8 columns instead of 2)
#     Line #1524 (got 1 columns instead of 2)
#     Line #1525 (got 1 columns instead of 2)
#     Line #1526 (got 13 columns instead of 2)
#     Line #1527 (got 4 columns instead of 2)
#     Line #1528 (got 26 columns instead of 2)
#     Line #1529 (got 41 columns instead of 2)
#     Line #1530 (got 1 columns instead of 2)
#     Line #1531 (got 11 columns instead of 2)
#     Line #1534 (got 9 columns instead of 2)
#     Line #1535 (got 4 columns instead of 2)
#     Line #1537 (got 5 columns instead of 2)
#     Line #1539 (got 7 columns instead of 2)
#     Line #1540 (got 7 columns instead of 2)
#     Line #1543 (got 8 columns instead of 2)
#     Line #1544 (got 3 columns instead of 2)
#     Line #1545 (got 12 columns instead of 2)
#     Line #1546 (got 51 columns instead of 2)
#     Line #1547 (got 1 columns instead of 2)
#     Line #1548 (got 1 columns instead of 2)
#     Line #1550 (got 3 columns instead of 2)
#     Line #1551 (got 1 columns instead of 2)
#     Line #1552 (got 1 columns instead of 2)
#     Line #1553 (got 1 columns instead of 2)
#     Line #1555 (got 1 columns instead of 2)
#     Line #1556 (got 7 columns instead of 2)
#     Line #1559 (got 8 columns instead of 2)
#     Line #1560 (got 3 columns instead of 2)
#     Line #1561 (got 12 columns instead of 2)
#     Line #1562 (got 42 columns instead of 2)
#     Line #1563 (got 1 columns instead of 2)
#     Line #1564 (got 1 columns instead of 2)
#     Line #1566 (got 3 columns instead of 2)
#     Line #1567 (got 1 columns instead of 2)
#     Line #1568 (got 1 columns instead of 2)
#     Line #1569 (got 1 columns instead of 2)
#     Line #1571 (got 1 columns instead of 2)
#     Line #1572 (got 7 columns instead of 2)
#     Line #1575 (got 8 columns instead of 2)
#     Line #1576 (got 3 columns instead of 2)
#     Line #1577 (got 12 columns instead of 2)
#     Line #1578 (got 78 columns instead of 2)
#     Line #1579 (got 1 columns instead of 2)
#     Line #1580 (got 1 columns instead of 2)
#     Line #1582 (got 3 columns instead of 2)
# ...
#     Line #1623 (got 8 columns instead of 2)
#     Line #1624 (got 3 columns instead of 2)
#     Line #1625 (got 12 columns instead of 2)
#     Line #1626 (got 92 columns instead of 2)
#     Line #1627 (got 1 columns instead of 2)
#     Line #1628 (got 1 columns instead of 2)
#     Line #1630 (got 3 columns instead of 2)
#     Line #1631 (got 1 columns instead of 2)
#     Line #1632 (got 1 columns instead of 2)
#     Line #1633 (got 1 columns instead of 2)
#     Line #1635 (got 1 columns instead of 2)
#     Line #1636 (got 7 columns instead of 2)
#     Line #1639 (got 8 columns instead of 2)
#     Line #1640 (got 3 columns instead of 2)
#     Line #1641 (got 12 columns instead of 2)
#     Line #1642 (got 46 columns instead of 2)
#     Line #1643 (got 1 columns instead of 2)
#     Line #1644 (got 1 columns instead of 2)
#     Line #1646 (got 3 columns instead of 2)
#     Line #1647 (got 1 columns instead of 2)
#     Line #1648 (got 1 columns instead of 2)
#     Line #1649 (got 1 columns instead of 2)
#     Line #1651 (got 1 columns instead of 2)
#     Line #1652 (got 1 columns instead of 2)
#     Line #1653 (got 1 columns instead of 2)
#     Line #1656 (got 1 columns instead of 2)
#     Line #1659 (got 1 columns instead of 2)
#     Line #1660 (got 1 columns instead of 2)
#     Line #1662 (got 1 columns instead of 2)
#     Line #1668 (got 5 columns instead of 2)
#     Line #1669 (got 5 columns instead of 2)
#     Line #1685 (got 1 columns instead of 2)
#     Line #1686 (got 1 columns instead of 2)
#     Line #1687 (got 1 columns instead of 2)
#     Line #1688 (got 6 columns instead of 2)
#     Line #1689 (got 1 columns instead of 2)
#     Line #1690 (got 1 columns instead of 2)
#     Line #1691 (got 1 columns instead of 2)
#     Line #1692 (got 1 columns instead of 2)
#     Line #1693 (got 1 columns instead of 2)
#     Line #1694 (got 1 columns instead of 2)
#     Line #1696 (got 30 columns instead of 2)
#     Line #1697 (got 4 columns instead of 2)
#     Line #1698 (got 1 columns instead of 2)
#     Line #1699 (got 7 columns instead of 2)
#     Line #1700 (got 1 columns instead of 2)
#     Line #1701 (got 4 columns instead of 2)
#     Line #1702 (got 4 columns instead of 2)
#     Line #1703 (got 1 columns instead of 2)
#     Line #1704 (got 7 columns instead of 2)
#     Line #1705 (got 6 columns instead of 2)
#     Line #1706 (got 1 columns instead of 2)
#     Line #1707 (got 6 columns instead of 2)
#     Line #1708 (got 3 columns instead of 2)
#     Line #1709 (got 4 columns instead of 2)
#     Line #1710 (got 4 columns instead of 2)
#     Line #1711 (got 4 columns instead of 2)
#     Line #1712 (got 1 columns instead of 2)
#     Line #1714 (got 1 columns instead of 2)
#     Line #1715 (got 1 columns instead of 2)
#     Line #1716 (got 6 columns instead of 2)
#     Line #1717 (got 1 columns instead of 2)
#     Line #1718 (got 1 columns instead of 2)
#     Line #1719 (got 1 columns instead of 2)
#     Line #1720 (got 1 columns instead of 2)
#     Line #1721 (got 1 columns instead of 2)
#     Line #1722 (got 1 columns instead of 2)
#     Line #1723 (got 1 columns instead of 2)
#     Line #1724 (got 1 columns instead of 2)
#     Line #1725 (got 4 columns instead of 2)
#     Line #1726 (got 1 columns instead of 2)
#     Line #1727 (got 1 columns instead of 2)
#     Line #1728 (got 4 columns instead of 2)
#     Line #1729 (got 1 columns instead of 2)
#     Line #1730 (got 1 columns instead of 2)
#     Line #1732 (got 3 columns instead of 2)
#     Line #1733 (got 1 columns instead of 2)
#     Line #1734 (got 1 columns instead of 2)
#     Line #1735 (got 1 columns instead of 2)
#     Line #1736 (got 1 columns instead of 2)
#     Line #1737 (got 1 columns instead of 2)
#     Line #1738 (got 1 columns instead of 2)
#     Line #1739 (got 1 columns instead of 2)
#     Line #1740 (got 1 columns instead of 2)
#     Line #1741 (got 1 columns instead of 2)
#     Line #1742 (got 1 columns instead of 2)
#     Line #1743 (got 1 columns instead of 2)
#     Line #1744 (got 1 columns instead of 2)
#     Line #1745 (got 1 columns instead of 2)
#     Line #1746 (got 1 columns instead of 2)
#     Line #1747 (got 1 columns instead of 2)
#     Line #1748 (got 1 columns instead of 2)
#     Line #1749 (got 1 columns instead of 2)
#     Line #1750 (got 4 columns instead of 2)
#     Line #1751 (got 1 columns instead of 2)
#     Line #1752 (got 1 columns instead of 2)
#     Line #1753 (got 1 columns instead of 2)
#     Line #1754 (got 1 columns instead of 2)
#     Line #1755 (got 1 columns instead of 2)
#     Line #1756 (got 1 columns instead of 2)
#     Line #1757 (got 1 columns instead of 2)
#     Line #1758 (got 1 columns instead of 2)
#     Line #1759 (got 1 columns instead of 2)
#     Line #1760 (got 1 columns instead of 2)
#     Line #1761 (got 1 columns instead of 2)
#     Line #1762 (got 1 columns instead of 2)
#     Line #1763 (got 1 columns instead of 2)
#     Line #1764 (got 1 columns instead of 2)
#     Line #1765 (got 1 columns instead of 2)
#     Line #1766 (got 1 columns instead of 2)
#     Line #1767 (got 1 columns instead of 2)
#     Line #1768 (got 1 columns instead of 2)
#     Line #1769 (got 1 columns instead of 2)
#     Line #1770 (got 1 columns instead of 2)
#     Line #1771 (got 1 columns instead of 2)
#     Line #1772 (got 1 columns instead of 2)
#     Line #1773 (got 1 columns instead of 2)
#     Line #1774 (got 1 columns instead of 2)
#     Line #1775 (got 1 columns instead of 2)
#     Line #1776 (got 1 columns instead of 2)
#     Line #1777 (got 1 columns instead of 2)
#     Line #1778 (got 1 columns instead of 2)
#     Line #1779 (got 1 columns instead of 2)
#     Line #1780 (got 1 columns instead of 2)
#     Line #1781 (got 1 columns instead of 2)
#     Line #1782 (got 1 columns instead of 2)
#     Line #1786 (got 1 columns instead of 2)
#     Line #1787 (got 1 columns instead of 2)
#     Line #1788 (got 1 columns instead of 2)
#     Line #1790 (got 4 columns instead of 2)
#     Line #1791 (got 1 columns instead of 2)
#     Line #1792 (got 1 columns instead of 2)
#     Line #1793 (got 1 columns instead of 2)
#     Line #1794 (got 1 columns instead of 2)
#     Line #1795 (got 4 columns instead of 2)
#     Line #1796 (got 1 columns instead of 2)
#     Line #1797 (got 1 columns instead of 2)
#     Line #1798 (got 1 columns instead of 2)
#     Line #1799 (got 1 columns instead of 2)
#     Line #1800 (got 1 columns instead of 2)
#     Line #1801 (got 1 columns instead of 2)
#     Line #1802 (got 1 columns instead of 2)
#     Line #1803 (got 1 columns instead of 2)
#     Line #1804 (got 1 columns instead of 2)
#     Line #1805 (got 1 columns instead of 2)
#     Line #1806 (got 1 columns instead of 2)
#     Line #1807 (got 1 columns instead of 2)
#     Line #1808 (got 1 columns instead of 2)
#     Line #1809 (got 1 columns instead of 2)
#     Line #1810 (got 1 columns instead of 2)
#     Line #1811 (got 1 columns instead of 2)
#     Line #1812 (got 1 columns instead of 2)
#     Line #1813 (got 1 columns instead of 2)
#     Line #1814 (got 1 columns instead of 2)
#     Line #1815 (got 1 columns instead of 2)
#     Line #1816 (got 1 columns instead of 2)
#     Line #1817 (got 1 columns instead of 2)
#     Line #1818 (got 1 columns instead of 2)
#     Line #1819 (got 1 columns instead of 2)
#     Line #1820 (got 1 columns instead of 2)
#     Line #1821 (got 1 columns instead of 2)
#     Line #1822 (got 1 columns instead of 2)
#     Line #1823 (got 1 columns instead of 2)
#     Line #1824 (got 1 columns instead of 2)
#     Line #1825 (got 1 columns instead of 2)
#     Line #1826 (got 1 columns instead of 2)
#     Line #1827 (got 3 columns instead of 2)
#     Line #1829 (got 4 columns instead of 2)
#     Line #1830 (got 4 columns instead of 2)
#     Line #1831 (got 4 columns instead of 2)
#     Line #1832 (got 4 columns instead of 2)
#     Line #1833 (got 1 columns instead of 2)
#     Line #1834 (got 3 columns instead of 2)
#     Line #1835 (got 1 columns instead of 2)
#     Line #1836 (got 1 columns instead of 2)
#     Line #1837 (got 4 columns instead of 2)
#     Line #1839 (got 1 columns instead of 2)
#     Line #1840 (got 1 columns instead of 2)
#     Line #1841 (got 1 columns instead of 2)
#     Line #1842 (got 1 columns instead of 2)
#     Line #1844 (got 1 columns instead of 2)
#     Line #1845 (got 1 columns instead of 2)
#     Line #1846 (got 1 columns instead of 2)
#     Line #1847 (got 1 columns instead of 2)
#     Line #1848 (got 1 columns instead of 2)
#     Line #1849 (got 1 columns instead of 2)
#     Line #1850 (got 3 columns instead of 2)
#     Line #1851 (got 3 columns instead of 2)
#     Line #1852 (got 3 columns instead of 2)
#     Line #1853 (got 5 columns instead of 2)
#     Line #1854 (got 1 columns instead of 2)
#     Line #1855 (got 1 columns instead of 2)
#     Line #1856 (got 5 columns instead of 2)
#     Line #1857 (got 5 columns instead of 2)
#     Line #1858 (got 1 columns instead of 2)
#     Line #1859 (got 1 columns instead of 2)
#     Line #1860 (got 1 columns instead of 2)
#     Line #1861 (got 11 columns instead of 2)
#     Line #1862 (got 1 columns instead of 2)
#     Line #1863 (got 1 columns instead of 2)
#     Line #1864 (got 4 columns instead of 2)
#     Line #1865 (got 1 columns instead of 2)
#     Line #1866 (got 1 columns instead of 2)
#     Line #1867 (got 1 columns instead of 2)
#     Line #1868 (got 1 columns instead of 2)
#     Line #1869 (got 1 columns instead of 2)
#     Line #1872 (got 1 columns instead of 2)
#     Line #1873 (got 1 columns instead of 2)
#     Line #1874 (got 1 columns instead of 2)
#     Line #1875 (got 1 columns instead of 2)
#     Line #1876 (got 11 columns instead of 2)
#     Line #1879 (got 1 columns instead of 2)
#     Line #1880 (got 1 columns instead of 2)
#     Line #1881 (got 1 columns instead of 2)
#     Line #1882 (got 1 columns instead of 2)
#     Line #1883 (got 1 columns instead of 2)
#     Line #1884 (got 1 columns instead of 2)
#     Line #1885 (got 1 columns instead of 2)
#     Line #1886 (got 1 columns instead of 2)
#     Line #1887 (got 1 columns instead of 2)
#     Line #1888 (got 1 columns instead of 2)
#     Line #1889 (got 1 columns instead of 2)
#     Line #1890 (got 1 columns instead of 2)
#     Line #1891 (got 1 columns instead of 2)
#     Line #1892 (got 1 columns instead of 2)
#     Line #1893 (got 1 columns instead of 2)
#     Line #1894 (got 1 columns instead of 2)
#     Line #1895 (got 1 columns instead of 2)
#     Line #1896 (got 1 columns instead of 2)
#     Line #1897 (got 1 columns instead of 2)
#     Line #1898 (got 1 columns instead of 2)
#     Line #1899 (got 1 columns instead of 2)
#     Line #1900 (got 3 columns instead of 2)
#     Line #1901 (got 3 columns instead of 2)
#     Line #1902 (got 3 columns instead of 2)
#     Line #1905 (got 1 columns instead of 2)
#     Line #1908 (got 1 columns instead of 2)
#     Line #1909 (got 3 columns instead of 2)
#     Line #1910 (got 3 columns instead of 2)
#     Line #1911 (got 3 columns instead of 2)
#     Line #1912 (got 10 columns instead of 2)
#     Line #1916 (got 1 columns instead of 2)
#     Line #1919 (got 1 columns instead of 2)
#     Line #1920 (got 1 columns instead of 2)
#     Line #1921 (got 1 columns instead of 2)
#     Line #1922 (got 1 columns instead of 2)
#     Line #1924 (got 1 columns instead of 2)
#     Line #1925 (got 4712 columns instead of 2)
#     Line #1926 (got 9841 columns instead of 2)
#     Line #1927 (got 1 columns instead of 2)
#     Line #1928 (got 1 columns instead of 2)
#     Line #1932 (got 1 columns instead of 2)
#     Line #1934 (got 1 columns instead of 2)
#     Line #1936 (got 1 columns instead of 2)
#     Line #1937 (got 1 columns instead of 2)
#     Line #1939 (got 1 columns instead of 2)
#     Line #1941 (got 9 columns instead of 2)
#     Line #1947 (got 8 columns instead of 2)
#     Line #1948 (got 5 columns instead of 2)
#     Line #1949 (got 6 columns instead of 2)
#     Line #1950 (got 12 columns instead of 2)
#     Line #1951 (got 63 columns instead of 2)
#     Line #1952 (got 1 columns instead of 2)
#     Line #1953 (got 1 columns instead of 2)
#     Line #1954 (got 1 columns instead of 2)
#     Line #1955 (got 3 columns instead of 2)
#     Line #1956 (got 1 columns instead of 2)
#     Line #1957 (got 1 columns instead of 2)
#     Line #1960 (got 4 columns instead of 2)
#     Line #1962 (got 8 columns instead of 2)
#     Line #1965 (got 8 columns instead of 2)
#     Line #1966 (got 1 columns instead of 2)
#     Line #1969 (got 8 columns instead of 2)
#     Line #1970 (got 1 columns instead of 2)
#     Line #1973 (got 8 columns instead of 2)
#     Line #1974 (got 1 columns instead of 2)
#     Line #1977 (got 8 columns instead of 2)
#     Line #1978 (got 1 columns instead of 2)
#     Line #1981 (got 8 columns instead of 2)
#     Line #1982 (got 1 columns instead of 2)
#     Line #1985 (got 8 columns instead of 2)
#     Line #1986 (got 1 columns instead of 2)
#     Line #1988 (got 3 columns instead of 2)
#     Line #1989 (got 1 columns instead of 2)
#     Line #1990 (got 1 columns instead of 2)
#     Line #1991 (got 1 columns instead of 2)
#     Line #1992 (got 5 columns instead of 2)
#     Line #1993 (got 1 columns instead of 2)
#     Line #1994 (got 1 columns instead of 2)
#     Line #1995 (got 1 columns instead of 2)
#     Line #1997 (got 1 columns instead of 2)
#     Line #1998 (got 1 columns instead of 2)
#     Line #1999 (got 1 columns instead of 2)
#     Line #2002 (got 1 columns instead of 2)
#     Line #2003 (got 1 columns instead of 2)
#     Line #2004 (got 1 columns instead of 2)
#     Line #2005 (got 5 columns instead of 2)
#     Line #2006 (got 1 columns instead of 2)
#     Line #2007 (got 1 columns instead of 2)
#     Line #2008 (got 1 columns instead of 2)
#     Line #2009 (got 6 columns instead of 2)
#     Line #2010 (got 1 columns instead of 2)
#     Line #2011 (got 1 columns instead of 2)
#     Line #2012 (got 1 columns instead of 2)
#     Line #2014 (got 1 columns instead of 2)
#     Line #2015 (got 1 columns instead of 2)
#     Line #2016 (got 1 columns instead of 2)
#     Line #2017 (got 1 columns instead of 2)
#     Line #2021 (got 9 columns instead of 2)
#     Line #2025 (got 6 columns instead of 2)
#     Line #2026 (got 12 columns instead of 2)
#     Line #2027 (got 53 columns instead of 2)
#     Line #2028 (got 1 columns instead of 2)
#     Line #2029 (got 6 columns instead of 2)
#     Line #2030 (got 12 columns instead of 2)
#     Line #2031 (got 40 columns instead of 2)
#     Line #2032 (got 1 columns instead of 2)
#     Line #2033 (got 1 columns instead of 2)
#     Line #2034 (got 8 columns instead of 2)
#     Line #2035 (got 1 columns instead of 2)
#     Line #2038 (got 8 columns instead of 2)
#     Line #2039 (got 4 columns instead of 2)
#     Line #2040 (got 9 columns instead of 2)
#     Line #2041 (got 11 columns instead of 2)
#     Line #2042 (got 12 columns instead of 2)
#     Line #2043 (got 40 columns instead of 2)
#     Line #2044 (got 1 columns instead of 2)
#     Line #2045 (got 1 columns instead of 2)
#     Line #2046 (got 4 columns instead of 2)
#     Line #2047 (got 1 columns instead of 2)
#     Line #2048 (got 1 columns instead of 2)
#     Line #2049 (got 1 columns instead of 2)
#     Line #2051 (got 8 columns instead of 2)
#     Line #2052 (got 7 columns instead of 2)
#     Line #2053 (got 1 columns instead of 2)
#     Line #2054 (got 1 columns instead of 2)
#     Line #2057 (got 5 columns instead of 2)
#     Line #2058 (got 9 columns instead of 2)
#     Line #2059 (got 14 columns instead of 2)
#     Line #2060 (got 72 columns instead of 2)
#     Line #2061 (got 1 columns instead of 2)
#     Line #2062 (got 16 columns instead of 2)
#     Line #2063 (got 28 columns instead of 2)
#     Line #2064 (got 1 columns instead of 2)
#     Line #2065 (got 1 columns instead of 2)
#     Line #2066 (got 1 columns instead of 2)
#     Line #2067 (got 1 columns instead of 2)
#     Line #2070 (got 13 columns instead of 2)
#     Line #2071 (got 13 columns instead of 2)
#     Line #2072 (got 72 columns instead of 2)
#     Line #2073 (got 1 columns instead of 2)
#     Line #2074 (got 15 columns instead of 2)
#     Line #2075 (got 28 columns instead of 2)
#     Line #2076 (got 1 columns instead of 2)
#     Line #2077 (got 1 columns instead of 2)
#     Line #2078 (got 1 columns instead of 2)
#     Line #2079 (got 1 columns instead of 2)
#     Line #2084 (got 1 columns instead of 2)
#     Line #2086 (got 7 columns instead of 2)
#     Line #2087 (got 6 columns instead of 2)
#     Line #2088 (got 1 columns instead of 2)
#     Line #2089 (got 1 columns instead of 2)

# %%
plt.plot(theta, rate)
plt.yscale('log')
plt.grid()

# %%
peaks,_=find_peaks(rate, height=0)
plt.plot(peaks, rate[peaks],"x")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-f122bf193f96> in <cell line: 0>()
# ----> 1 peaks,_=find_peaks(rate, height=0)
#       2 plt.plot(peaks, rate[peaks],"x")
#
# NameError: name 'rate' is not defined

# %% [markdown]
# KBr crystal
# tube	Mo
# diafragm	2
# interplanar spacing	329
# voltage	35
# current	1
# coupling mode	1 :2
# angle range 3 - 75
# increment	0.1

# %%
filename = 'kbr.txt'
theta,rate = np.genfromtxt(filename, unpack=True, skip_header=3)

# %%
plt.plot(theta, rate)
#plt.yscale('log')
plt.grid()
